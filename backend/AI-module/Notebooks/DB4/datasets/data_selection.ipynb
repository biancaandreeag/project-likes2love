# %%
from Lists.abbreviations import INTERNET_SLANG
from Lists.emoticons import EMOTICONS
from Lists.emojis import EMO_UNICODE
import pandas as pd
import contractions
import unicodedata
import re

# %%
df = pd.read_csv('./twitter_racism_parsed_dataset.csv')

df = df.drop(columns=['index','Annotation','id'])
df = df.rename(columns={'oh_label': 'label', 'Text': 'text'})

df['type'] = df['label'].apply(lambda x: 'ethnicity' if x == 1 else 'not_cyberbullying')
df = df[df['type'] != 'not_cyberbullying']

df['label'] = df['label'].replace(1, 4)

df.head()
# Out:
#                                                  text  label       type
# 0   @AAlwuhaib1977 Muslim mob violence against Hin...      4  ethnicity
# 2   @jncatron @isra_jourisra @AMPalestine Islamoph...      4  ethnicity
# 8   @HuffPostRelig Islam invaded and conquered 2/3...      4  ethnicity
# 9   @semzyxx Do you approve of your pedophile prop...      4  ethnicity
# 10  @watan71969 @geeky_zekey Problem with vile Mus...      4  ethnicity

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1970 entries, 0 to 13465
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    1970 non-null   object
#  1   label   1970 non-null   int64
#  2   type    1970 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 61.6+ KB

# %%
df.to_csv('twitter_ethnicity.csv', index=False)
